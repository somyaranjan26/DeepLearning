# %% [markdown]
# <a href="https://colab.research.google.com/github/somyaranjan26/DeepLearning/blob/master/Lung_disease_classification_and_quantification_with_explainable_AI/VGG19_Pneumonia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **Pneumonia And Nomral Classification Model in VGG19 using Chest X-Ray Images**

# %% [markdown]
# ### Connect to Google Drive to access Dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd '/content/drive/My Drive/Deep Learning Internship/Training'
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive
# /content/drive/My Drive/Deep Learning Internship/Training

# %% [markdown]
# ### Import all dependencies

# %%
from __future__ import print_function, division
from builtins import range, input

from tensorflow.keras.layers import Input, Lambda, Dense, Flatten, GlobalAveragePooling2D, Dropout
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.applications import VGG19
from tensorflow.keras.applications.vgg16 import preprocess_input
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from sklearn.metrics import confusion_matrix, roc_curve
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

from glob import glob
import pandas as pd
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# ### Define Few Parameters

# %%
#define size to which images are to be resized
IMAGE_SIZE = [224, 224] # feel free to change depending on dataset

# training config:
epochs = 100
batch_size = 32

#define paths
pneumonia_path = 'Pneumonia'
nonpneumonia_path = 'Normal'

# Use glob to grab images from path .jpg or jpeg
pneumonia_files = glob(pneumonia_path + '/*')
nonpneumonia_files = glob(nonpneumonia_path + '/*')

# %% [markdown]
# ### Fetch Images and Class Labels from Files (This might take a while)

# %%
# Preparing Labels
pneumonia_labels = []
nonpneumonia_labels = []

pneumonia_images=[]
nonpneumonia_images=[]

import cv2 

for i in range(len(pneumonia_files)):
  image = cv2.imread(pneumonia_files[i])
  image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
  image = cv2.resize(image,(224,224))
  pneumonia_images.append(image)
  pneumonia_labels.append('Chest_Pneumonia')
for i in range(len(nonpneumonia_files)):
  image = cv2.imread(nonpneumonia_files[i])
  image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
  image = cv2.resize(image,(224,224))
  nonpneumonia_images.append(image)
  nonpneumonia_labels.append('Chest_NonPneumonia')

print(len(pneumonia_labels))
print(len(nonpneumonia_labels))
# Out:
# 645
# 645

# %% [markdown]
# ### Visualize First 40 Images from Data set

# %%
# look at a random image for fun
def plot_images(images, title):
    nrows, ncols = 5, 8
    figsize = [10, 6]

    fig, ax = plt.subplots(nrows=nrows, ncols=ncols, figsize=figsize, facecolor=(1, 1, 1))

    for i, axi in enumerate(ax.flat):
        axi.imshow(images[i])
        axi.set_axis_off()

    plt.suptitle(title, fontsize=24)
    plt.tight_layout(pad=0.2, rect=[0, 0, 1, 0.9])
    plt.show()
plot_images(pneumonia_images, 'Positive pneumonia Chest X-ray')
plot_images(nonpneumonia_images, 'Negative pneumonia Chest X-ray')

# %% [markdown]
# ### **Normalization**
# #### Model takes images in the form of array of pixels. Hence convert into array and *normalize*

# %%
# Convert to array and Normalize to interval of [0,1]
pneumonia_images = np.array(pneumonia_images) / 255
nonpneumonia_images = np.array(nonpneumonia_images) / 255

# %% [markdown]
# ### **Train Test Split**

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer
from tensorflow.keras.utils import to_categorical

# split into training and testing
pneumonia_x_train, pneumonia_x_test, pneumonia_y_train, pneumonia_y_test = train_test_split(
    pneumonia_images, pneumonia_labels, test_size=0.2)
nonpneumonia_x_train, nonpneumonia_x_test, nonpneumonia_y_train, nonpneumonia_y_test = train_test_split(
    nonpneumonia_images, nonpneumonia_labels, test_size=0.2)


X_train = np.concatenate((nonpneumonia_x_train, pneumonia_x_train), axis=0)
X_test = np.concatenate((nonpneumonia_x_test, pneumonia_x_test), axis=0)
y_train = np.concatenate((nonpneumonia_y_train, pneumonia_y_train), axis=0)
y_test = np.concatenate((nonpneumonia_y_test, pneumonia_y_test), axis=0)

# make labels into categories - either 0 or 1
y_train = LabelBinarizer().fit_transform(y_train)
y_train = to_categorical(y_train)

y_test = LabelBinarizer().fit_transform(y_test)
y_test = to_categorical(y_test)

# %% [markdown]
# ### Visualize a few images from Training and Test sets

# %%
plot_images(pneumonia_x_train, 'X_train')
plot_images(pneumonia_x_test, 'X_test')
# y_train and y_test contain class lables 0 and 1 representing Pneumonia and NonPneumonia for X_train and X_test

# %% [markdown]
# ### **Building and Visualizing model**

# %%
vggModel = VGG19(weights="imagenet", include_top=False,
    input_tensor=Input(shape=(224, 224, 3)))

outputs = vggModel.output
outputs = Flatten(name="flatten")(outputs)
outputs = Dropout(0.5)(outputs)
outputs = Dense(2, activation="softmax")(outputs)

model = Model(inputs=vggModel.input, outputs=outputs)

for layer in vggModel.layers:
    layer.trainable = False

model.compile(
        loss='categorical_crossentropy', 
        optimizer='adam', 
        metrics=['accuracy']
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80142336/80134624 [==============================] - 0s 0us/step

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv4 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv4 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv4 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# dropout (Dropout)            (None, 25088)             0
# _________________________________________________________________
# dense (Dense)                (None, 2)                 50178
# =================================================================
# Total params: 20,074,562
# Trainable params: 50,178
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %% [markdown]
# ### **Image Augmentation**
# To train on images at different positions, angles, flips, etc

# %%
train_aug = ImageDataGenerator(
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True
)

# %% [markdown]
# ### **Training the model**

# %%
history = model.fit(train_aug.flow(X_train, y_train, batch_size=32),
                    validation_data=(X_test, y_test),
                    validation_steps=len(X_test) / 32,
                    steps_per_epoch=len(X_train) / 32,
                    epochs=100)
# Out:
# Epoch 1/100
# 33/32 [==============================] - 50s 2s/step - loss: 1.2580 - accuracy: 0.5911 - val_loss: 0.7870 - val_accuracy: 0.7054
# Epoch 2/100
# 33/32 [==============================] - 49s 1s/step - loss: 0.4529 - accuracy: 0.8033 - val_loss: 0.2495 - val_accuracy: 0.9147
# Epoch 3/100
# 33/32 [==============================] - 50s 2s/step - loss: 0.3781 - accuracy: 0.8488 - val_loss: 0.2722 - val_accuracy: 0.8798
# Epoch 4/100
# 33/32 [==============================] - 49s 1s/step - loss: 0.3288 - accuracy: 0.8643 - val_loss: 0.2760 - val_accuracy: 0.8760
# Epoch 5/100
# 33/32 [==============================] - 50s 2s/step - loss: 0.3348 - accuracy: 0.8663 - val_loss: 0.3349 - val_accuracy: 0.8566
# Epoch 6/100
# 33/32 [==============================] - 49s 1s/step - loss: 0.3224 - accuracy: 0.8760 - val_loss: 0.2632 - val_accuracy: 0.8876
# Epoch 7/100
# 33/32 [==============================] - 49s 1s/step - loss: 0.3156 - accuracy: 0.8876 - val_loss: 0.1897 - val_accuracy: 0.9496
# Epoch 8/100
# 33/32 [==============================] - 49s 1s/step - loss: 0.2913 - accuracy: 0.8857 - val_loss: 0.1862 - val_accuracy: 0.9302
# Epoch 9/100
# 33/32 [==============================] - 50s 2s/step - loss: 0.2787 - accuracy: 0.8953 - val_loss: 0.1834 - val_accuracy: 0.9380
# Epoch 10/100
# 33/32 [==============================] - 50s 2s/step - loss: 0.2977 - accuracy: 0.8973 - val_loss: 0.2021 - val_accuracy: 0.9302
# Epoch 11/100
# 33/32 [==============================] - 50s 2s/step - loss: 0.2720 - accuracy: 0.8953 - val_loss: 0.2000 - val_accuracy: 0.9341
# Epoch 12/100
# 33/32 [==============================] - 50s 2s/step - loss: 0.2854 - accuracy: 0.8895 - val_loss: 0.1883 - val_accuracy: 0.9302
# Epoch 13/100
# 33/32 [==============================] - 50s 2s/step - loss: 0.2522 - accuracy: 0.8944 - val_loss: 0.1620 - val_accuracy: 0.9496
# Epoch 14/100
# 33/32 [==============================] - 50s 2s/step - loss: 0.3360 - accuracy: 0.8634 - val_loss: 0.1853 - val_accuracy: 0.9302
# Epoch 15/100
# 33/32 [==============================] - 49s 1s/step - loss: 0.2544 - accuracy: 0.9002 - val_loss: 0.1731 - val_accuracy: 0.9380
# Epoch 16/100
# 33/32 [==============================] - 50s 2s/step - loss: 0.2998 - accuracy: 0.8895 - val_loss: 0.1689 - val_accuracy: 0.9496
# Epoch 17/100
# 33/32 [==============================] - 49s 1s/step - loss: 0.3164 - accuracy: 0.8798 - val_loss: 0.1640 - val_accuracy: 0.9457
# Epoch 18/100
# 33/32 [==============================] - 49s 1s/step - loss: 0.3228 - accuracy: 0.8692 - val_loss: 0.1692 - val_accuracy: 0.9457
# Epoch 19/100
# 33/32 [==============================] - 50s 2s/step - loss: 0.2838 - accuracy: 0.8905 - val_loss: 0.1848 - val_accuracy: 0.9380
# Epoch 20/100
# 33/32 [==============================] - 50s 2s/step - loss: 0.2653 - accuracy: 0.8992 - val_loss: 0.1767 - val_accuracy: 0.9419
# Epoch 21/100
# 33/32 [==============================] - 50s 2s/step - loss: 0.2387 - accuracy: 0.9079 - val_loss: 0.1647 - val_accuracy: 0.9496
# Epoch 22/100
# 33/32 [==============================] - 49s 1s/step - loss: 0.3071 - accuracy: 0.8857 - val_loss: 0.3807 - val_accuracy: 0.8643
# Epoch 23/100
# 33/32 [==============================] - 49s 1s/step - loss: 0.2528 - accuracy: 0.9089 - val_loss: 0.1640 - val_accuracy: 0.9457
# Epoch 24/100
# 33/32 [==============================] - 49s 1s/step - loss: 0.2331 - accuracy: 0.9099 - val_loss: 0.1551 - val_accuracy: 0.9535
# Epoch 25/100
# 33/32 [==============================] - 49s 1s/step - loss: 0.2243 - accuracy: 0.9138 - val_loss: 0.1916 - val_accuracy: 0.9419
# Epoch 26/100
# 33/32 [==============================] - 49s 1s/step - loss: 0.2596 - accuracy: 0.9021 - val_loss: 0.1516 - val_accuracy: 0.9612
# Epoch 27/100
# 33/32 [==============================] - 49s 1s/step - loss: 0.2753 - accuracy: 0.8983 - val_loss: 0.1558 - val_accuracy: 0.9651
# Epoch 28/100
# 33/32 [==============================] - 50s 2s/step - loss: 0.2825 - accuracy: 0.8876 - val_loss: 0.1756 - val_accuracy: 0.9341
# Epoch 29/100
# 33/32 [==============================] - 50s 2s/step - loss: 0.2735 - accuracy: 0.9012 - val_loss: 0.1904 - val_accuracy: 0.9302
# Epoch 30/100
# 33/32 [==============================] - 50s 2s/step - loss: 0.2845 - accuracy: 0.9002 - val_loss: 0.1497 - val_accuracy: 0.9651
# Epoch 31/100
# 33/32 [==============================] - 49s 1s/step - loss: 0.2456 - accuracy: 0.9118 - val_loss: 0.1612 - val_accuracy: 0.9496
# Epoch 32/100
# 33/32 [==============================] - 49s 1s/step - loss: 0.2756 - accuracy: 0.8992 - val_loss: 0.2287 - val_accuracy: 0.9147
# Epoch 33/100
# 33/32 [==============================] - 49s 1s/step - loss: 0.3015 - accuracy: 0.8992 - val_loss: 0.1530 - val_accuracy: 0.9496
# Epoch 34/100
# 33/32 [==============================] - 50s 2s/step - loss: 0.3740 - accuracy: 0.8915 - val_loss: 0.3002 - val_accuracy: 0.8992
# Epoch 35/100
# 33/32 [==============================] - 49s 1s/step - loss: 0.2897 - accuracy: 0.9002 - val_loss: 0.1908 - val_accuracy: 0.9419
# Epoch 36/100
# 33/32 [==============================] - 49s 1s/step - loss: 0.2660 - accuracy: 0.9070 - val_loss: 0.2128 - val_accuracy: 0.9341
# Epoch 37/100
# 33/32 [==============================] - 50s 2s/step - loss: 0.2448 - accuracy: 0.9050 - val_loss: 0.2213 - val_accuracy: 0.9302
# Epoch 38/100
# 33/32 [==============================] - 50s 2s/step - loss: 0.3222 - accuracy: 0.8934 - val_loss: 0.2066 - val_accuracy: 0.9264
# Epoch 39/100
# 33/32 [==============================] - 50s 2s/step - loss: 0.2497 - accuracy: 0.9079 - val_loss: 0.1469 - val_accuracy: 0.9651
# Epoch 40/100
# 33/32 [==============================] - 50s 2s/step - loss: 0.2162 - accuracy: 0.9099 - val_loss: 0.1555 - val_accuracy: 0.9496
# Epoch 41/100
# 33/32 [==============================] - 49s 1s/step - loss: 0.2364 - accuracy: 0.9167 - val_loss: 0.1642 - val_accuracy: 0.9496
# Epoch 42/100
# 33/32 [==============================] - 48s 1s/step - loss: 0.2650 - accuracy: 0.9079 - val_loss: 0.1962 - val_accuracy: 0.9341
# Epoch 43/100
# 33/32 [==============================] - 49s 1s/step - loss: 0.2952 - accuracy: 0.8915 - val_loss: 0.2284 - val_accuracy: 0.9302
# Epoch 44/100
# 33/32 [==============================] - 49s 1s/step - loss: 0.2653 - accuracy: 0.8944 - val_loss: 0.2261 - val_accuracy: 0.9264
# Epoch 45/100
# 33/32 [==============================] - 49s 1s/step - loss: 0.2741 - accuracy: 0.8905 - val_loss: 0.1616 - val_accuracy: 0.9535
# Epoch 46/100
# 33/32 [==============================] - 50s 2s/step - loss: 0.3002 - accuracy: 0.9041 - val_loss: 0.1678 - val_accuracy: 0.9574
# Epoch 47/100
# 33/32 [==============================] - 50s 2s/step - loss: 0.2722 - accuracy: 0.9021 - val_loss: 0.1545 - val_accuracy: 0.9574
# Epoch 48/100
# 33/32 [==============================] - 49s 1s/step - loss: 0.2629 - accuracy: 0.9012 - val_loss: 0.1844 - val_accuracy: 0.9457
# Epoch 49/100
# 33/32 [==============================] - 49s 1s/step - loss: 0.2297 - accuracy: 0.9196 - val_loss: 0.1504 - val_accuracy: 0.9651
# Epoch 50/100
# 33/32 [==============================] - 49s 1s/step - loss: 0.2375 - accuracy: 0.9079 - val_loss: 0.1597 - val_accuracy: 0.9535
# Epoch 51/100
# 33/32 [==============================] - 48s 1s/step - loss: 0.2679 - accuracy: 0.9079 - val_loss: 0.1485 - val_accuracy: 0.9574
# Epoch 52/100
# 33/32 [==============================] - 49s 1s/step - loss: 0.2805 - accuracy: 0.9041 - val_loss: 0.3432 - val_accuracy: 0.8837
# Epoch 53/100
# 33/32 [==============================] - 50s 2s/step - loss: 0.2647 - accuracy: 0.9079 - val_loss: 0.1540 - val_accuracy: 0.9612
# Epoch 54/100
# 33/32 [==============================] - 49s 1s/step - loss: 0.2420 - accuracy: 0.9118 - val_loss: 0.2085 - val_accuracy: 0.9457
# Epoch 55/100
# 33/32 [==============================] - 50s 2s/step - loss: 0.2307 - accuracy: 0.9167 - val_loss: 0.1420 - val_accuracy: 0.9651
# Epoch 56/100
# 33/32 [==============================] - 50s 2s/step - loss: 0.2520 - accuracy: 0.9118 - val_loss: 0.1377 - val_accuracy: 0.9574
# Epoch 57/100
# 33/32 [==============================] - 50s 2s/step - loss: 0.3579 - accuracy: 0.8731 - val_loss: 0.1401 - val_accuracy: 0.9612
# Epoch 58/100
# 33/32 [==============================] - 50s 2s/step - loss: 0.3273 - accuracy: 0.8886 - val_loss: 0.1664 - val_accuracy: 0.9574
# Epoch 59/100
# 33/32 [==============================] - 49s 1s/step - loss: 0.3280 - accuracy: 0.8905 - val_loss: 0.1837 - val_accuracy: 0.9496
# Epoch 60/100
# 33/32 [==============================] - 49s 1s/step - loss: 0.2155 - accuracy: 0.9138 - val_loss: 0.1880 - val_accuracy: 0.9496
# Epoch 61/100
# 33/32 [==============================] - 49s 1s/step - loss: 0.2581 - accuracy: 0.9167 - val_loss: 0.1779 - val_accuracy: 0.9457
# Epoch 62/100
# 33/32 [==============================] - 50s 2s/step - loss: 0.2970 - accuracy: 0.9060 - val_loss: 0.1529 - val_accuracy: 0.9690
# Epoch 63/100
# 33/32 [==============================] - 49s 1s/step - loss: 0.2802 - accuracy: 0.9070 - val_loss: 0.1646 - val_accuracy: 0.9612
# Epoch 64/100
# 33/32 [==============================] - 51s 2s/step - loss: 0.2883 - accuracy: 0.9109 - val_loss: 0.1536 - val_accuracy: 0.9457
# Epoch 65/100
# 33/32 [==============================] - 51s 2s/step - loss: 0.2893 - accuracy: 0.8983 - val_loss: 0.4908 - val_accuracy: 0.8566
# Epoch 66/100
# 33/32 [==============================] - 50s 2s/step - loss: 0.2885 - accuracy: 0.9041 - val_loss: 0.1759 - val_accuracy: 0.9496
# Epoch 67/100
# 33/32 [==============================] - 50s 2s/step - loss: 0.2722 - accuracy: 0.9041 - val_loss: 0.1939 - val_accuracy: 0.9457
# Epoch 68/100
# 33/32 [==============================] - 49s 1s/step - loss: 0.2836 - accuracy: 0.9167 - val_loss: 0.1495 - val_accuracy: 0.9574
# Epoch 69/100
# 33/32 [==============================] - 49s 1s/step - loss: 0.2499 - accuracy: 0.9147 - val_loss: 0.1728 - val_accuracy: 0.9457
# Epoch 70/100
# 33/32 [==============================] - 50s 2s/step - loss: 0.2597 - accuracy: 0.9215 - val_loss: 0.3186 - val_accuracy: 0.9070
# Epoch 71/100
# 33/32 [==============================] - 50s 2s/step - loss: 0.2870 - accuracy: 0.9012 - val_loss: 0.1640 - val_accuracy: 0.9535
# Epoch 72/100
# 33/32 [==============================] - 49s 1s/step - loss: 0.2970 - accuracy: 0.9021 - val_loss: 0.4142 - val_accuracy: 0.8721
# Epoch 73/100
# 33/32 [==============================] - 50s 2s/step - loss: 0.4444 - accuracy: 0.8643 - val_loss: 0.7621 - val_accuracy: 0.7829
# Epoch 74/100
# 33/32 [==============================] - 51s 2s/step - loss: 0.4032 - accuracy: 0.8721 - val_loss: 0.3900 - val_accuracy: 0.8992
# Epoch 75/100
# 33/32 [==============================] - 50s 2s/step - loss: 0.2878 - accuracy: 0.9109 - val_loss: 0.3061 - val_accuracy: 0.9147
# Epoch 76/100
# 33/32 [==============================] - 50s 2s/step - loss: 0.2539 - accuracy: 0.9234 - val_loss: 0.2566 - val_accuracy: 0.9186
# Epoch 77/100
# 33/32 [==============================] - 49s 1s/step - loss: 0.2465 - accuracy: 0.9176 - val_loss: 0.1607 - val_accuracy: 0.9612
# Epoch 78/100
# 33/32 [==============================] - 49s 1s/step - loss: 0.2565 - accuracy: 0.9060 - val_loss: 0.2222 - val_accuracy: 0.9380
# Epoch 79/100
# 33/32 [==============================] - 49s 1s/step - loss: 0.2277 - accuracy: 0.9254 - val_loss: 0.1781 - val_accuracy: 0.9574
# Epoch 80/100
# 33/32 [==============================] - 49s 1s/step - loss: 0.3433 - accuracy: 0.8934 - val_loss: 0.1942 - val_accuracy: 0.9457
# Epoch 81/100
# 33/32 [==============================] - 49s 1s/step - loss: 0.2452 - accuracy: 0.9060 - val_loss: 0.1704 - val_accuracy: 0.9535
# Epoch 82/100
# 33/32 [==============================] - 49s 1s/step - loss: 0.2316 - accuracy: 0.9234 - val_loss: 0.1460 - val_accuracy: 0.9651
# Epoch 83/100
# 33/32 [==============================] - 49s 1s/step - loss: 0.3068 - accuracy: 0.8934 - val_loss: 0.1746 - val_accuracy: 0.9574
# Epoch 84/100
# 33/32 [==============================] - 50s 2s/step - loss: 0.3025 - accuracy: 0.8944 - val_loss: 0.3337 - val_accuracy: 0.8992
# Epoch 85/100
# 33/32 [==============================] - 50s 2s/step - loss: 0.2843 - accuracy: 0.9060 - val_loss: 0.1981 - val_accuracy: 0.9496
# Epoch 86/100
# 33/32 [==============================] - 50s 2s/step - loss: 0.3280 - accuracy: 0.9021 - val_loss: 0.2433 - val_accuracy: 0.9380
# Epoch 87/100
# 33/32 [==============================] - 50s 2s/step - loss: 0.2774 - accuracy: 0.9012 - val_loss: 0.1663 - val_accuracy: 0.9612
# Epoch 88/100
# 33/32 [==============================] - 51s 2s/step - loss: 0.2194 - accuracy: 0.9264 - val_loss: 0.1740 - val_accuracy: 0.9574
# Epoch 89/100
# 33/32 [==============================] - 52s 2s/step - loss: 0.2332 - accuracy: 0.9176 - val_loss: 0.2831 - val_accuracy: 0.9225
# Epoch 90/100
# 33/32 [==============================] - 51s 2s/step - loss: 0.2689 - accuracy: 0.9041 - val_loss: 0.2539 - val_accuracy: 0.9302
# Epoch 91/100
# 33/32 [==============================] - 51s 2s/step - loss: 0.2344 - accuracy: 0.9186 - val_loss: 0.3208 - val_accuracy: 0.9031
# Epoch 92/100
# 33/32 [==============================] - 49s 1s/step - loss: 0.2632 - accuracy: 0.9099 - val_loss: 0.2009 - val_accuracy: 0.9574
# Epoch 93/100
# 33/32 [==============================] - 49s 1s/step - loss: 0.3008 - accuracy: 0.9099 - val_loss: 0.2384 - val_accuracy: 0.9380
# Epoch 94/100
# 33/32 [==============================] - 50s 2s/step - loss: 0.2392 - accuracy: 0.9215 - val_loss: 0.3921 - val_accuracy: 0.8953
# Epoch 95/100
# 33/32 [==============================] - 49s 1s/step - loss: 0.3642 - accuracy: 0.9041 - val_loss: 0.1895 - val_accuracy: 0.9535
# Epoch 96/100
# 33/32 [==============================] - 49s 1s/step - loss: 0.3239 - accuracy: 0.9060 - val_loss: 0.1472 - val_accuracy: 0.9690
# Epoch 97/100
# 33/32 [==============================] - 48s 1s/step - loss: 0.2678 - accuracy: 0.9118 - val_loss: 0.2062 - val_accuracy: 0.9496
# Epoch 98/100
# 33/32 [==============================] - 48s 1s/step - loss: 0.2671 - accuracy: 0.9089 - val_loss: 0.1941 - val_accuracy: 0.9496
# Epoch 99/100
# 33/32 [==============================] - 49s 1s/step - loss: 0.2299 - accuracy: 0.9264 - val_loss: 0.1518 - val_accuracy: 0.9574
# Epoch 100/100
# 33/32 [==============================] - 49s 1s/step - loss: 0.2484 - accuracy: 0.9234 - val_loss: 0.2963 - val_accuracy: 0.9109

# %%
model.save('vgg_pneumonia100.h5')

# %%
model.save_weights('vggweights_pneumonia100.hdf5')

# %%
model = load_model('vgg_pneumonia100.h5')

# %% [markdown]
# ### **Making Predicions**

# %%
y_pred = model.predict(X_test, batch_size=batch_size)

# %% [markdown]
# ### Visulaizing First 10 predictions

# %%
prediction=y_pred[0:10]
for index, probability in enumerate(prediction):
  if probability[1] > 0.5:
        plt.title('%.2f' % (probability[1]*100) + '% Pneumonia')
  else:
        plt.title('%.2f' % ((1-probability[1])*100) + '% Non Pneumonia')
  plt.imshow(X_test[index])
  plt.show()

# %%
# Convert to Binary classes
y_pred_bin = np.argmax(y_pred, axis=1)
y_test_bin = np.argmax(y_test, axis=1)

# %% [markdown]
# ### Plot ROC Curve

# %%
fpr, tpr, thresholds = roc_curve(y_test_bin, y_pred_bin)
plt.plot(fpr, tpr)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.rcParams['font.size'] = 12
plt.title('ROC curve for Pneumonia100 model')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.grid(True)

# %% [markdown]
# ### Plot Confusion Matrix

# %%
def plot_confusion_matrix(normalize):
  classes = ['Pneumonia','NonPneumonia']
  tick_marks = [0.5,1.5]
  cn = confusion_matrix(y_test_bin, y_pred_bin,normalize=normalize)
  sns.heatmap(cn,cmap='plasma',annot=True)
  plt.xticks(tick_marks, classes)
  plt.yticks(tick_marks, classes)
  plt.title('Confusion Matrix')
  plt.ylabel('True label')
  plt.xlabel('Predicted label')
  plt.show()

print('Confusion Matrix without Normalization')
plot_confusion_matrix(normalize=None)

print('Confusion Matrix with Normalized Values')
plot_confusion_matrix(normalize='true')
# Out:
# Confusion Matrix without Normalization
# Confusion Matrix with Normalized Values

# %% [markdown]
# ### **Classification Report**

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test_bin, y_pred_bin))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.98      0.92       129
#            1       0.98      0.84      0.90       129
#
#     accuracy                           0.91       258
#    macro avg       0.92      0.91      0.91       258
# weighted avg       0.92      0.91      0.91       258

# %% [markdown]
# ### **Accuracy and Loss Plots**

# %%
plt.figure(figsize=(10,10))

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])

plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')

plt.legend(['Training', 'Testing'])
plt.savefig('vgg_pneumonia100_accuracy.png')
plt.show()

# %%
plt.figure(figsize=(10,10))

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')

plt.legend(['Training', 'Testing'])
plt.savefig('vgg_pneumonia100_loss.png')
plt.show()
